# %%
print("Hello World")
# Out:
# Hello World

# %%
#List
fruits = ['Apple','Mango','Apple',32,31,32,34,True]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Apple', 32, 31, 32, 34, True]

# %%
type(fruits)
# Out:
# list

# %%
fruits[1] = 'Grapes'
print(fruits)
# Out:
# ['Apple', 'Grapes', 'Apple', 32, 31, 32, 34, True]

# %%
fruits.insert(2,'Banana')
print(fruits)
# Out:
# ['Apple', 'Grapes', 'Banana', 'Apple', 32, 31, 32, 34, True]

# %%
fruits.append('Kiwi')
print(fruits)
# Out:
# ['Apple', 'Grapes', 'Banana', 'Apple', 32, 31, 32, 34, True, 'Kiwi']

# %%
fruits.remove('Kiwi')
fruits.remove('Grapes')
print(fruits)
# Out:
# ['Apple', 'Banana', 'Apple', 32, 31, 32, 34, True]

# %%
fruits.pop(3)
print(fruits)
# Out:
# ['Apple', 'Banana', 'Apple', 31, 32, 34, True]

# %%
#Tuple
fruits = ('Apple','Mango','Banana','Kiwi','Banana',32,34,53,12,True,False)
print(fruits)
type(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Kiwi', 'Banana', 32, 34, 53, 12, True, False)
# tuple

# %%
fruits = ('Apple','Mango','Banana','Kiwi','Banana',32,34,53,12,True,False)
x = list(fruits)
x[3] = 'Grapes'
fruits = tuple(x)
print(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Grapes', 'Banana', 32, 34, 53, 12, True, False)

# %%
x = list(fruits)
x.insert(2,'Banana')
fruits = tuple(x)
print(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Banana', 'Grapes', 'Banana', 32, 34, 53, 12, True, False)

# %%
x = list(fruits)
x.append('Kiwi')
fruits = tuple(x)
print(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Banana', 'Grapes', 'Banana', 32, 34, 53, 12, True, False, 'Kiwi')

# %%
x = list(fruits)
x.remove('Grapes')
fruits = tuple(x)
print(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Banana', 'Banana', 32, 34, 53, 12, True, False, 'Kiwi')

# %%
x = list(fruits)
x.pop(3)
fruits = tuple(x)
print(fruits)
# Out:
# ('Apple', 'Mango', 'Banana', 'Banana', 32, 34, 53, 12, True, False, 'Kiwi')

# %%
#Set
fruits = {'Apple','Mango','Banana','Kiwi','Banana',32,34,53,12,True,False}
print(fruits)
# Out:
# {32, 'Kiwi', 34, True, False, 'Banana', 12, 53, 'Mango', 'Apple'}

# %%
fruits.add('Grapes')
print(fruits)
# Out:
# {32, 'Kiwi', 34, True, False, 'Grapes', 'Banana', 12, 53, 'Mango', 'Apple'}

# %%
num ={1,2,3,4,5,6}
fruits.update(num)
print(fruits)
# Out:
# {32, 'Kiwi', 34, True, False, 'Grapes', 'Banana', 2, 3, 4, 5, 6, 12, 53, 'Mango', 'Apple'}

# %%
fruits.remove('Apple')
print(fruits)
# Out:
# {32, 'Kiwi', 34, True, False, 'Grapes', 'Banana', 2, 3, 4, 5, 6, 12, 53, 'Mango'}

# %%
fruits.discard(32)
print(fruits)
# Out:
# {'Kiwi', 34, True, False, 'Grapes', 'Banana', 2, 3, 4, 5, 6, 12, 53, 'Mango'}

# %%
#Dictionary
car = {
    'brand': 'Ford',
    'Model': 'Mustang',
    'year': 1964
}
print(car)
# Out:
# {'brand': 'Ford', 'Model': 'Mustang', 'year': 1964}

# %%
car.keys()
# Out:
# dict_keys(['brand', 'Model', 'year'])

# %%
car.values()
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
car.items()
# Out:
# dict_items([('brand', 'Ford'), ('Model', 'Mustang'), ('year', 1964)])

# %%
car['brand'] = 'Kia'
print(car)
# Out:
# {'brand': 'Kia', 'Model': 'Mustang', 'year': 1964}

# %%
car.update({'Model': 'Sonet'})
print(car)
# Out:
# {'brand': 'Kia', 'Model': 'Sonet', 'year': 1964}

# %%
car['color'] = 'Red'
print(car)
# Out:
# {'brand': 'Kia', 'Model': 'Sonet', 'year': 1964, 'color': 'Red'}

# %%
car.update({'tyre':4})
print(car)
# Out:
# {'brand': 'Kia', 'Model': 'Sonet', 'year': 1964, 'color': 'Red', 'tyre': 4}

# %%
car.pop('Model')
print(car)
# Out:
# {'brand': 'Kia', 'year': 1964, 'color': 'Red', 'tyre': 4}

# %%
car.popitem()
print(car)
# Out:
# {'brand': 'Kia', 'year': 1964, 'color': 'Red'}

# %%
# Conditional Statements
a = 95
if a > 90:
    print("I will get a mercedes")
else:
    print("I will get a bike")
# Out:
# I will get a mercedes

# %%
#Loops
for i in "london":
    print(i)
# Out:
# l
# o
# n
# d
# o
# n

# %%
for a in 'USA':
    print("Hello",a)
# Out:
# Hello U
# Hello S
# Hello A
